# %%
from konlpy.tag import Hannanum
from collections import Counter
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
import pandas as pd
bosu1 = pd.read_csv('김보수_추천영상리스트_1일차.csv', engine='python', encoding='utf-8')
bosu1.head()
# Out:
#                                             추천 영상 제목                     채널명
# 0  긴급! 윤석열 방금 청년콘서트에서 충격 발언! 김진욱 공수처장, 홍준표 박지원 멘붕...                   진성호방송
# 1                             오징어 게임 | 공식 예고편 | 넷플릭스  Netflix Korea 넷플릭스 코리아
# 2  [미스터리 환경 #2] 급증하는 유방암에 자화자찬 무식 정부 [박석순교수의 진짜 환...                펜앤드마이크TV
# 3  2022 민주당 대선 후보 1위 이재명 불륜 인정? "옛날에 여배우 만났다" - 손...                  뉴스타운TV
# 4                       [황교안 일기_9월7일] 4.15 총선 전면 무효!                   황교안TV

# %%
stopwords_kr =['2021.','09.','11','12','10','9월','진짜']

def displayWordCloud(data = None, color = 'white', w=1200, h=800):
    wordcloud = WordCloud(
        font_path='c:/Windows/Fonts/malgun.ttf',
        stopwords=stopwords_kr,
        background_color=color,
        width=w, height=h).generate(data)
    plt.figure(figsize=(15,10))
    plt.imshow(wordcloud)
    plt.axis('off')
    plt.show()

# %%
df.shape
# Out:
# (143, 2)

# %%
displayWordCloud(''.join(df['채널명']))

# %%
displayWordCloud(''.join(df['추천 영상 제목']))
